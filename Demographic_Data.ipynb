# %% [markdown]
# <a href="https://colab.research.google.com/github/mayankdeshmukh/Data-Science-and-Machine-Learning/blob/main/Demographic_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing packages

import pandas as pd

# %%
stats = pd.read_csv("/content/DemographicData.csv")

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#Number of rows

len(stats)
# Out:
# 195

# %%
#See columns

stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#Renaming columns

stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers', 'IncomeGroup']

# %%
#Number of columns

len(stats.columns)
# Out:
# 5

# %%
#Top rows

stats.head(6) #Number of rows can be specified - Default is 5
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
#Bottom rows

stats.tail(6) #Number of rows can be specified - Default is 5
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 189             Samoa         WSM     26.172           15.3
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
#Information on columns

stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#Statistics on dataframe

stats.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
stats.describe().transpose()
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %%
#Subsetting dataframes in pandas
#rows

stats[2:4] #Specify rows to be printed
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 2      Angola         AGO     45.985           19.1  Upper middle income
# 3     Albania         ALB     12.877           57.2  Upper middle income

# %%
#Subsetting dataframes in pandas
#Columns

stats.columns[2:3]
# Out:
# Index(['BirthRate'], dtype='object')

# %%
stats[:7] #From beginning to specified rows
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
# 5             Argentina         ARG     17.716           59.9
# 6               Armenia         ARM     13.308           41.9
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
stats[188:] #From specified row till the end
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 188  West Bank and Gaza         PSE     30.394           46.6
# 189               Samoa         WSM     26.172           15.3
# 190         Yemen, Rep.         YEM     32.947           20.0
# 191        South Africa         ZAF     20.850           46.5
# 192    Congo, Dem. Rep.         COD     42.394            2.2
# 193              Zambia         ZMB     40.471           15.4
# 194            Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats[1:5]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[['BirthRate', 'InternetUsers']]
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
stats.iloc[:,2:4]
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
stats.iloc[190:194,3:5]
# Out:
#      InternetUsers          IncomeGroup
# 190           20.0  Lower middle income
# 191           46.5  Upper middle income
# 192            2.2           Low income
# 193           15.4  Lower middle income

# %%
stats.iloc[190:194,[3,4]]
# Out:
#      InternetUsers          IncomeGroup
# 190           20.0  Lower middle income
# 191           46.5  Upper middle income
# 192            2.2           Low income
# 193           15.4  Lower middle income

# %%
stats.iloc[190:194,3:]
# Out:
#      InternetUsers          IncomeGroup
# 190           20.0  Lower middle income
# 191           46.5  Upper middle income
# 192            2.2           Low income
# 193           15.4  Lower middle income

# %%
stats['New'] = stats.BirthRate / stats.InternetUsers

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup       New
# 0          High income  0.129835
# 1           Low income  5.975085
# 2  Upper middle income  2.407592
# 3  Upper middle income  0.225122
# 4          High income  0.125500

# %%
stats1 = stats.drop('New', 1)
# Out:
# <ipython-input-25-d203a4282a13>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   stats1 = stats.drop('New', 1)

# %%
stats1.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
filter1 = stats.InternetUsers < 2
filter1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
stats1[filter1]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
stats[stats.InternetUsers < 2]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income
#
#            New
# 11   33.962308
# 52   38.666667
# 55   17.328947
# 64   23.335625
# 117  11.324375
# 127  29.212353
# 154  21.605294
# 156  29.260667
# 172  32.504545

# %%
stats[(stats.InternetUsers<2) & (stats.BirthRate<20)]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 117     Myanmar         MMR     18.119            1.6  Lower middle income
#
#            New
# 117  11.324375

# %%
stats[(stats.InternetUsers<2) | (stats.BirthRate<20)]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244           78.9
# 3                           Albania         ALB     12.877           57.2
# 4              United Arab Emirates         ARE     11.044           88.0
# 5                         Argentina         ARG     17.716           59.9
# 6                           Armenia         ARM     13.308           41.9
# ..                              ...         ...        ...            ...
# 181                   United States         USA     12.500           84.2
# 183  St. Vincent and the Grenadines         VCT     16.306           52.0
# 184                   Venezuela, RB         VEN     19.842           54.9
# 185           Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                         Vietnam         VNM     15.537           43.9
#
#              IncomeGroup       New
# 0            High income  0.129835
# ...

# %%
stats1.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(stats['BirthRate'])
# Out:
# (array([48., 29., 28., 25., 13., 13., 19., 11.,  6.,  3.]),
#  array([ 7.9   , 12.0761, 16.2522, 20.4283, 24.6044, 28.7805, 32.9566,
#         37.1327, 41.3088, 45.4849, 49.661 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(stats['BirthRate'])
# Out:
# <ipython-input-36-5769eacd423e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(stats['BirthRate'])
# <Axes: xlabel='BirthRate', ylabel='Density'>

# %%
sns.boxplot(data = stats, x = 'IncomeGroup', y='BirthRate')
# Out:
# <Axes: xlabel='IncomeGroup', ylabel='BirthRate'>

# %%
sns.barplot(data = stats, x = 'IncomeGroup', y = 'BirthRate')
# Out:
# <Axes: xlabel='IncomeGroup', ylabel='BirthRate'>

# %%
sns.lmplot(data = stats, x = 'InternetUsers', y = 'BirthRate')

# %%
sns.lmplot(data = stats, x = 'InternetUsers', y = 'BirthRate', fit_reg = False)

# %%
sns.lmplot(data = stats, x = 'InternetUsers', y = 'BirthRate', fit_reg = False, hue = 'IncomeGroup')

# %%
sns.lmplot(data = stats, x = 'InternetUsers', y = 'BirthRate', fit_reg = False, hue = 'IncomeGroup', scatter_kws = {'s':200})
